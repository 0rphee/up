# %%
import pandas as pd

df = pd.read_csv("MXvideos.csv", encoding='latin-1')
df.head(2)
# Out:
#       video_id trending_date  \
# 0  SbOwzAl9ZfQ      17.14.11
# 1  klOV6Xh-DnI      17.14.11
#
#                                                title  \
# 0                     CapÃ­tulo 12 | MasterChef 2017
# 1  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
#
#               channel_title  category_id              publish_time  \
# 0           MasterChef 2017           24  2017-11-13T06:06:22.000Z
# 1  Micky Contreras Martinez           22  2017-11-13T05:11:58.000Z
#
#                                                 tags   views  likes  dislikes  \
# 0  MasterChef Junior 2017|"TV Azteca"|"recetas"|"...  310130   4182       361
# 1                                    La Voz Mexico 7  104972    271       174
#
#    comment_count                                  thumbnail_link  \
# 0           1836  https://i.ytimg.com/vi/SbOwzAl9ZfQ/default.jpg
# 1            369  https://i.ytimg.com/vi/klOV6Xh-DnI/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# ...

# %%
df[['title', 'likes', 'dislikes']]
# Out:
#                                                    title  likes  dislikes
# 0                         CapÃ­tulo 12 | MasterChef 2017   4182       361
# 1      ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...    271       174
# 2               LOUIS CKAGÃ - EL PULSO DE LA REPÃBLICA  10105       266
# 3       Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017    378       171
# 4               DOG HACKS | MUSAS LESSLIE LOS POLINESIOS  57781       681
# ...                                                  ...    ...       ...
# 40446  Shawn Mendes x Portugal (FPF Official World Cu...  65639       547
# 40447  AMLO llegÃ³ con su esposa al Tercer Debate en ...   3558        58
# 40448  Maire usa una blusa kawaiii Â¿adorable o ridÃ­...    538         6
# 40449       La Jefa del CampeÃ³n - CapÃ­tulo 2 Parte 3/4     94        11
# 40450  Â¿POR QUÃ SHANKS ES TAN RESPETADO POR TODOS E...   5398       148
#
# [40451 rows x 3 columns]

# %%
len(df[df["channel_title"] == "Televisa Telenovelas"])
# Out:
# 149

# %%
df[df["channel_title"] == "Franco Escamilla"].sort_values(by="dislikes", ascending=False)
# Out:
#           video_id trending_date  \
# 36262  LaiiNJkGBD8      18.23.05
# 17771  C4sWGmu88uY      18.13.02
# 36033  LaiiNJkGBD8      18.22.05
# 11206  XkKh5nf0Ufg      18.09.01
# 9092   vDWFFudGQT4      17.29.12
# ...            ...           ...
# 29662  r6o0nBgbZn8      18.19.04
# 26495  gEHNjqqR1vE      18.28.03
# 20231       #NAME?      18.25.02
# 25850  EzjSoIZtgxg      18.25.03
# 27845  2wAMb8bgfEQ      18.04.04
#
#                                                    title     channel_title  \
# 36262                       La Mesa ReÃ±oÃ±a Piloto + 99  Franco Escamilla
# 17771             Franco Escamilla.- Â¡Y ya! parte final  Franco Escamilla
# 36033                       La Mesa ReÃ±oÃ±a Piloto + 99  Franco Escamilla
# 11206  Franco Escamilla.- Â¡Y ya!  quinta parte Han Solo  Franco Escamilla
# 9092   No me digas.- Episodio 15 - No Me Digas Renova...  Franco Escamilla
# ...                                                  ...               ...
# ...

# %%
df[((df['channel_title'] == 'Ventaneando')|(df['channel_title'] == 'Franco Escamilla'))&(df['likes'] >= 1500)]
# Out:
#           video_id trending_date  \
# 10     rZZEeeAVgog      17.14.11
# 246    oyvN5ExU4fE      17.15.11
# 493    oa-WPEBVBz4      17.16.11
# 617    PwervJzDYYI      17.17.11
# 1640   Fa3jJK3yfuU      17.22.11
# ...            ...           ...
# 37537  nus2heF73Ig      18.30.05
# 37831  TAtssrCJCPE      18.31.05
# 39124  WkJd-wuTmZk      18.07.06
# 40175  k52tFts-kw0      18.13.06
# 40436  iFItPMcJRDo      18.14.06
#
#                                                    title     channel_title  \
# 10            Franco Escamilla.- Tradiciones y Faitelson  Franco Escamilla
# 246               Franco Escamilla.- La mesa reÃ±oÃ±a 75  Franco Escamilla
# 493                      El Show De La Mole.- PROGRAMA 2  Franco Escamilla
# 617    No me digas.- Episodio 9 - Familiares IncÃ³mod...  Franco Escamilla
# 1640              Franco Escamilla.- La mesa reÃ±oÃ±a 76  Franco Escamilla
# ...                                                  ...               ...
# ...
